# %%
## 1. Pull btc, eth, doge, and shib related tweets from Mark Cuban and Plan B and store them in csv files.

# %%
# Import twint and nest asyncio in order to scrape tweets based on specific search criteria
import twint
import nest_asyncio

# %%
# Run nest asyncio to enable concurrent actions and avoid runtime error
nest_asyncio.apply()

# %%
# Define search criteria to pull btc related tweets from Marck Cuban
## Dates are set using trial and error since twint only returns a certain number of tweets at a time
search_criteria = "btc (from:mcuban) until:2021-06-03 since:2020-10-10"
# Configure twint instance, including writing data to a csv
c = twint.Config()
c.Search = search_criteria
c.Store_csv = True
c.Output = "mcuban.csv"

# Run twint instance saving data to csv
twint.run.Search(c)

#Rename csv file per dates pulled from twitter, update search criteria above accordingly, and re-run twint instance
# Out:
# 1393673151691755521 2021-05-15 16:02:27 -0500 <mcuban> @ANANDDB I never was anti crypto. Ive owned it for years. What I said was that btc had little utility other than as a store of value. What am I talking about now? Utility. And I don’t shill anything.  I said doge was better than a lottery ticket. Then people started using it to buy things
# 1392611938983632896 2021-05-12 17:45:34 -0500 <mcuban> We at  https://t.co/VUydpLFzGh will continue to accept BTC/Eth/Doge because we know that replacing Gold as a store of value will help the environment   https://t.co/bs7NvnJY8A and   https://t.co/ELhbuLOBRV shrinking big bank and coin usage will benefit society and the environment
# 1389006710795296769 2021-05-02 18:59:41 -0500 <mcuban> @spindel5 I still don't like btc as a currency. That's always been the issue.  And people aren't using it as currency. No one really buys anything with it. Would you spend your btc ?
# 1389004112654655489 2021-05-02 18:49:21 -0500 <mcuban> Crypto succeeds when it's a more productive implementation of it's competition. BTC/Gold are both financial religions. BTC is easy to trade/store/create with no delivery issues. BTC also enables transfer of value locally and globally . Gold is a hassle. Just look at Ft Knox
# 1387861184976760834 2021-04-29 15:07:46 -0500 <mcuban> Great. But you will put the $1m into a smart contract and we will take feeds for your stocks and my choice of half eth/btc and the winner's charity gets paid in 10 years, right ?  I'm not taking anybody's word that they will pay up in 10 yrs.  Sorry.
# 1387778236093014016 2021-04-29 09:38:09 -0500 <mcuban> How about this. We set up a ln eth smart contract. You put in $1m in a stablecoin. I put up $1m in a stablecoin. We write the contract to pay you if the increase in the S&amp;P 500 is higher at the end date than the increase in YOUR choice of BTC or ETH. You can pick the custodian
# 1387766099761061889 2021-04-29 08:49:56 -0500 <mcuban> @PeterMallouk Yup. All in on Netflix and Amazon. Sold most of my other stocks I bought in March. Hedged interest rate risk. Told everyone that my stock buying thesis is to buy companies great at AI. Used some cash to buy more btc, eth, MKR Holding some cash for next downturn. Rinse/Repeat
# 1387432242197139464 2021-04-28 10:43:18 -0500 <mcuban> If you look at crypto assets whether eth, doge, btc,mkr etc and only see something intangible  for people to trade, you haven't really looked. If you see smart contracts and programming languages and  think of new ways to disrupt industries then I'm saying there's a chance
# 1387277151683100672 2021-04-28 00:27:01 -0500 <mcuban> @CoinDesk @TheEllenShow This is exactly why people will buy physical products with doge coin and not with btc and rarely with eth.   It’s hard for someone with $100 to get excited about owning a fraction of btc or eth.  It’s easy with doge. When it appreciates that makes those items easy 2 buy
# 1386052796294651906 2021-04-24 15:21:52 -0500 <mcuban> @merket @jakeudell @chamath And my 2014 position on btc was as right then as it is now. It’s a store of value and not a currency. But I do wish I had taken more of a flyer on it :). Fortunately I did buy a bunch of eth
# 1366857486586757123 2021-03-02 15:06:34 -0500 <mcuban> @CryptoHarper What i said a couple years ago was that it wasnt a currency and didnt have any immediate utility. Unlike a banana that i could eat :). What has changed is De-Fi. Now BTC/Eth/Others can make you your own personal banker and facilitate many other types of trx Thats utility
# 1366787249644445703 2021-03-02 10:27:28 -0500 <mcuban> Let me help Peter. Gold is hyped as much as Crypto. Do we really need gold jewelry? Gold can make you a ring. BTC/Eth are technologies that can make you a banker, allow friction free exchange of value and are extensible into an unlimited range of biz and personal applications
# 1343603085281734666 2020-12-28 11:01:53 -0500 <mcuban> No disagreement. I love to mess with btc-twitter.  They dont want to admit it is a supply and demand play, just like every other tradeable asset.   https://t.co/HAosxBB9XR   applies to btc today like it did to stocks 16yrs ago "Fundamentals is a word sellers use to attract buyers"
# 1343290421498155009 2020-12-27 14:19:28 -0500 <mcuban> @yungNleveraged You do realize that physical shares aren’t trading any longer. That any company could address any of these issues in many different ways and many are already addressed. And by the way, both BTC and shares are subject to the regulation
# 1341770350766469121 2020-12-23 09:39:15 -0500 <mcuban> Want to spend your $BTC somewhere... Spend it with the Mavs and get a 25 percent discount for using Bitcoin !   https://t.co/De7Y5f28s8
# 1340708605960609793 2020-12-20 11:20:15 -0500 <mcuban> @diveej3 We have been accepting btc for mavs tickets and merch  for YEARS.  You do realize a MAJOR reason for the move in btc,Bach, eth is the move in interest rates ? Or have you ignored the pricing moves in all other alt assets?
# 1340013801178075146 2020-12-18 13:19:21 -0500 <mcuban> @AriDavidPaul @gladstein @Talk_BTC All of course is hypothetical.  But the bigger point is that IMO, any asset is worth what someone will pay for it. The change in pricing rarely reflects the underlying qualities of that asset.  Same as stocks. Get long and get loud has more impact than anything else
# 1340013308469010435 2020-12-18 13:17:23 -0500 <mcuban> @AriDavidPaul @gladstein @Talk_BTC What percent of new buyers actually own btc ? They use ETFs , fractional and other means to avoid the complexities. Yes the ETF could possibly hold in street name for them. But will they ? And the supply/demand dynamics could change
# 1340012369737641986 2020-12-18 13:13:39 -0500 <mcuban> @gladstein @StrictlyBidnazz @Talk_BTC Don’t agree. To a bad actor it’s a cost benefit analysis.
# 1340009812457910273 2020-12-18 13:03:30 -0500 <mcuban> @gladstein @StrictlyBidnazz @Talk_BTC Again , if you can identify those who control 83% of hashing , you can influence those people in a variety of ways. If greed is good, there may be other incentives to miners.  It’s not like mining is becoming more lucrative
# 1340006988940517377 2020-12-18 12:52:16 -0500 <mcuban> @ZackG1982 @gladstein @StrictlyBidnazz @Talk_BTC I stand corrected. 83pct of hashing power  decided to make the change. But that doesn’t change the point. It actually strengthens it.
# 1340004603321049093 2020-12-18 12:42:48 -0500 <mcuban> @gladstein @StrictlyBidnazz @Talk_BTC This is where we disagree. Look at the 2017 agreement. When you can identify and communicate with 83% of the market cap of btc, that means you can find them and influence them and that influence may or may not go the way you want it to. That is a huge risk. Self interest &lt;&gt; Greed
# 1340003475585966082 2020-12-18 12:38:19 -0500 <mcuban> @gladstein @StrictlyBidnazz @Talk_BTC Self interest and greed are not always one and the same.
# 1340002920008454145 2020-12-18 12:36:06 -0500 <mcuban> @StrictlyBidnazz @gladstein @Talk_BTC Social good ? It’s the right thing to do to help others ?
# 1339999528062234626 2020-12-18 12:22:38 -0500 <mcuban> @gladstein @Talk_BTC Ok Nostradamus :)
# 1339997165465325568 2020-12-18 12:13:14 -0500 <mcuban> @gladstein @AriDavidPaul @Talk_BTC And you think the outcome will always be the same ?
# 1339995729587269632 2020-12-18 12:07:32 -0500 <mcuban> @AriDavidPaul @gladstein @Talk_BTC If the only expected value from btc and the blockchain is financial, you would “likely” be right. However, it is not the only value.  Is there a scenario where whales and the majority of stakeholders’ interest diverge ? I think that’s inevitable
# 1339987963510460423 2020-12-18 11:36:40 -0500 <mcuban> @gladstein @Talk_BTC Unless of course the majority of people who own btc decide that the 21m limit should be changed.  It is a democratic currency. Why let the HODLers benefit more than the earners
# 1339983285917786115 2020-12-18 11:18:05 -0500 <mcuban> @aantonop @gladstein Ive never said it cant be used, but few are able to. And the amount of fractions of btc they earn per hr is obviously declining.  But as you make clear, PayPal, which, i know supports btc, is an alternative. Thats the point. There are alternatives available with more coming.
# 1339981176593854467 2020-12-18 11:09:42 -0500 <mcuban> @gladstein @Talk_BTC It is revolutionary.  But like all other technologies, it has to compete with an unlimited number of new entrants that can learn from BTC and every crypto and do better. Maybe it does stay on top. People invested in Ether and others feel differently
# 1339977071393722369 2020-12-18 10:53:24 -0500 <mcuban> @j_howe4 @BitcoinMacGyver @gladstein You ignore current and future  competition and the possible impact it can have on the range of possible btc outcomes
# 1339975919805591552 2020-12-18 10:48:49 -0500 <mcuban> @JCapitalCompany @gladstein @Talk_BTC Maybe. Or maybe there will be national digital currencies with established exchanges and btc becomes worthless ?
# 1339973755079192576 2020-12-18 10:40:13 -0500 <mcuban> @gladstein @Talk_BTC Doesn’t matter how you can divide it if you have to convert it to use it.  I know and understand the technical nuances of btc.  But it truly is fun to play with the zealots who think it is uniquely qualified to be anything more than possibly the most popular crypto-currency
# 1339972956399820800 2020-12-18 10:37:02 -0500 <mcuban> @gladstein @JackHar10524114 @MrHodl @AlanFreestone BTC , like any non-currency asset, has its strengths and weaknesses. What is ignored is that it has hundreds of other crypto competitors that offer similar features .
# 1339972516773847041 2020-12-18 10:35:18 -0500 <mcuban> @gladstein @JackHar10524114 @MrHodl @AlanFreestone Yup. Or you could send them dollars or euros. They each have varying transfer costs, but only btc has to be converted to be used and the massive fluctuations  in price makes it difficult for someone in Belarus  to plan ahead. Dollar and Euros don't typically have 10pct moves
# 1339971385779761154 2020-12-18 10:30:48 -0500 <mcuban> @Talk_BTC @gladstein And every week that check buys less and less btc, doesn't it ?
# 1339966831147282432 2020-12-18 10:12:42 -0500 <mcuban> @sammyboy_jr @BitcoinMacGyver @gladstein Nor do the HODLers have to sell any btc,
# 1339953510553673730 2020-12-18 09:19:46 -0500 <mcuban> @jhamel It's actually late. More than 85pct of the btc that will ever be created already has been  and is being HODLed.
# 1339953060458672130 2020-12-18 09:17:59 -0500 <mcuban> @JackHar10524114 @MrHodl @AlanFreestone @gladstein Or we can ignore the fact that btc is useless without first being converted to US dollars.  HODLers celebrate the price in dollars.  You have noticed this fact , right ?
# 1339952223418273792 2020-12-18 09:14:39 -0500 <mcuban> @_ConnerBrown_ Spoiler alert: btc is not supposed to be like fiat currency
# 1339948940779802625 2020-12-18 09:01:37 -0500 <mcuban> @Alexwashere @gladstein And they all value that effort in fiat and convert to btc. Not the other way around
# 1339948144424071176 2020-12-18 08:58:27 -0500 <mcuban> @BitcoinMacGyver @gladstein So the people who have Bitcoin effectively control all the value and hoped for impact of Bitcoin ? If they hodl, the price goes up, making it harder for those who need it most to have access ?  Tell me how the person with zero savings gains value from btc ?
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
# Define search criteria to pull btc related tweets from PlanB
## Dates are set using trial and error since twint only returns a certain number of tweets at a time
search_criteria = "btc (from:100trillionUSD) until:2021-02-05 since:2020-10-10"
# Configure twint instance, including writing data to a csv
c = twint.Config()
c.Search = search_criteria
c.Store_csv = True
c.Output = "planb.csv"

# Run twint instance saving data to csv
twint.run.Search(c)

#Rename csv file per dates pulled from twitter, update search criteria above accordingly, and re-run twint instance
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
# Import pandas to manipulate data
import pandas as pd

# %%
# Read all csv's containing btc tweets from mcuban and combine them into one dataframe
mcuban_btc_1 = pd.read_csv('mcuban btc 05152021-12182020.csv')
mcuban_btc_2 = pd.read_csv('mcuban btc 09172021-06032021.csv')
mcuban_btc_tweets = pd.concat([mcuban_btc_2, mcuban_btc_1])
# Write final dataframe to csv
mcuban_btc_tweets.to_csv('mcuban_btc_tweets.csv', index=False)

# %%
# Read all csv's containing btc tweets from PlanB and combine them into one dataframe
planb_btc_1 = pd.read_csv('planb btc 02052021-10152020.csv')
planb_btc_2 = pd.read_csv('planb btc 04112021-02142021.csv')
planb_btc_3 = pd.read_csv('planb btc 09282021-04132021.csv')
planb_btc_tweets = pd.concat([planb_btc_3, planb_btc_2, planb_btc_1])
# Write final dataframe to csv
planb_btc_tweets.to_csv('planb_btc_tweets.csv', index=False)

# %%
# Define search criteria to pull eth related tweets from mcuban
## There are less tweets concerning eth so we only need to run this search once
search_criteria = "eth (from:mcuban) until:2021-10-20 since:2020-10-10"
# Configure twint instance, including writing data to a csv
c = twint.Config()
c.Search = search_criteria
c.Store_csv = True
c.Output = "mcuban.csv"

# Run twint instance saving data to csv
twint.run.Search(c)

#Rename csv file to mcuban_eth_tweets.csv so that future twint executions don't overwrite the data as twint is buggy
# Out:
# 1340708605960609793 2020-12-20 11:20:15 -0500 <mcuban> @diveej3 We have been accepting btc for mavs tickets and merch  for YEARS.  You do realize a MAJOR reason for the move in btc,Bach, eth is the move in interest rates ? Or have you ignored the pricing moves in all other alt assets?
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
# Define search criteria to pull eth related tweets from PlanB
## There are less tweets concerning eth so we only need to run this search once
search_criteria = "eth (from:100trillionUSD) until:2021-10-10 since:2020-10-10"
# Configure twint instance, including writing data to a csv
c = twint.Config()
c.Search = search_criteria
c.Store_csv = True
c.Output = "planb.csv"

# Run twint instance saving data to csv
twint.run.Search(c)

# Rename csv file to planb_eth_tweets.csv so that future twint executions don't overwrite the data as twint is buggy
# Out:
# 1421761930788749312 2021-08-01 04:17:14 -0500 <100trillionUSD> @GregoryPeterJ @ETH_Ghost @G_CFP_MSc That is such BS!! The work / model stands on its own. All data and formulae are available. Everybody can verify or falsify. My name, credentials or credibility add nothing.
# 1392641441206312962 2021-05-12 19:42:48 -0500 <100trillionUSD> @sebirocs It is a marketing trick of Eth: PoS to play the green game. Dumb ESG funds will not understand the importance of PoW and fall for the PoS green ESG bullshit.
# 1392638519483539457 2021-05-12 19:31:11 -0500 <100trillionUSD> @xrpmule Xrp and Eth are dead as a decentralized P2P system, they are instead just a centralized database with full control for the database owner, which is exactly what governments want, but what bitcoin was designed to circumvent.
# 1392636271231737861 2021-05-12 19:22:15 -0500 <100trillionUSD> @xrpmule Yes, without PoW bitcoin would be dead like Xrp and Eth, no longer P2P and forced to live on a big server in a big data center of some company with a CEO that we have to trust to give us addresses/accounts, to give us our balance info, and to not debase the money supply: DEAD.
# 1392495498389557251 2021-05-12 10:02:52 -0500 <100trillionUSD> ETH is now ~0.08 BTC and might even pump to 2017 peak levels of 0.12 BTC. But beware that after a pump altcoins frequently return to their normal BTC denominated ranges (or lower). #Cointegration #PairsTrading  https://t.co/fk36Yq6EcE
# 1386761737416892422 2021-04-26 14:18:57 -0500 <100trillionUSD> After this 2020 Vitalik tweet (BTC $9K) 2 things happened:  1) BTC price increased 6x to $54K (exactly like S2F model predicted) 2) Vitalik decided to change ETH money supply to look more like bitcoin, i.e. to become "scarce" (note that he could decide to change ETH supply again)
# 1318136636161622016 2020-10-19 05:27:18 -0500 <100trillionUSD> @antanst The cost (capex and opex) of 51% BTC mining is much larger than 51% ETH mining. So the cost of a 51% ETH attack is much much lower than for BTC
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
# Define search criteria to pull doge related tweets from mcuban
## There are less tweets concerning doge so we only need to run this search once
search_criteria = "doge (from:mcuban) until:2021-03-04 since:2020-10-10"
# Configure twint instance, including writing data to a csv
c = twint.Config()
c.Search = search_criteria
c.Store_csv = True
c.Output = "mcuban.csv"

# Run twint instance saving data to csv
twint.run.Search(c)

#Rename csv file to mcuban_doge_tweets.csv so that future twint executions don't overwrite the data as twint is buggy
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
# Define search criteria to pull doge related tweets from PlanB
## There are less tweets concerning eth so we only need to run this search once
search_criteria = "doge (from:100trillionUSD) until:2021-10-10 since:2020-10-10"
# Configure twint instance, including writing data to a csv
c = twint.Config()
c.Search = search_criteria
c.Store_csv = True
c.Output = "planb.csv"

# Run twint instance saving data to csv
twint.run.Search(c)

# Rename csv file to planb_doge_tweets.csv so that future twint executions don't overwrite the data as twint is buggy
# Out:
# 1393318153418121226 2021-05-14 16:31:49 -0500 <100trillionUSD> Roger Ver -&gt; BCH Mark Zuckerberg -&gt; Libra Calvin Ayre -&gt; BSV Elon Musk -&gt; Doge All trying to create "the next bitcoin", bitcoin 2.0, their own coin. Have they not learned? Why not build on #bitcoin help make BTC better? We know how this ends #networkeffect  https://t.co/ulpqA8Jx6r
# 1391071281282420738 2021-05-08 11:43:32 -0500 <100trillionUSD> @roymaj 1 $Doge now buys you 1150 Sats !!
# 1390980861101740038 2021-05-08 05:44:15 -0500 <100trillionUSD> @naiiveclub Sats is the next Doge
# 1390980299421589505 2021-05-08 05:42:01 -0500 <100trillionUSD> @unstoppablebtc Sats &gt; Doge
# 1389706960883306512 2021-05-04 17:22:13 -0500 <100trillionUSD> @nakugo2d buy doge if you must .. and give us your #bitcoin 😎
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
# Define search criteria to pull doge related tweets from mcuban
## There are less tweets concerning shib so we only need to run this search once
search_criteria = "shib (from:mcuban) until:2021-03-04 since:2020-10-10"
# Configure twint instance, including writing data to a csv
c = twint.Config()
c.Search = search_criteria
c.Store_csv = True
c.Output = "mcuban.csv"

# Run twint instance saving data to csv
twint.run.Search(c)

# mcuban has never tweeted about shib
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
# Define search criteria to pull shib related tweets from PlanB
## There are less tweets concerning eth so we only need to run this search once
search_criteria = "shib (from:100trillionUSD) until:2021-10-10 since:2020-10-10"
# Configure twint instance, including writing data to a csv
c = twint.Config()
c.Search = search_criteria
c.Store_csv = True
c.Output = "planb.csv"

# Run twint instance saving data to csv
twint.run.Search(c)

# planb has never tweeted about shib
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
## 2. Clean data and run sentiment analysis on tweets.

# %%
# Load csv with all of Mark Cuban's btc tweets into a dataframe
mcuban_btc = pd.read_csv('mcuban_btc_tweets.csv')
mcuban_btc.head()
# Out:
#                     id      conversation_id  \
# 0  1439061911232933889  1439061911232933889
# 1  1427050797242662913  1426600841650319367
# 2  1427050023552966665  1426600841650319367
# 3  1427048363762061312  1426600841650319367
# 4  1426998624341405702  1426600841650319367
#
#                                   created_at        date      time  timezone  \
# 0  2021-09-17 22:01:10 Central Daylight Time  2021-09-17  22:01:10      -500
# 1  2021-08-15 18:33:18 Central Daylight Time  2021-08-15  18:33:18      -500
# 2  2021-08-15 18:30:13 Central Daylight Time  2021-08-15  18:30:13      -500
# 3  2021-08-15 18:23:37 Central Daylight Time  2021-08-15  18:23:37      -500
# 4  2021-08-15 15:05:59 Central Daylight Time  2021-08-15  15:05:59      -500
#
#     user_id username        name  place  ... geo source user_rt_id user_rt  \
# 0  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 1  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 2  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 3  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 4  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
#
#   retweet_id                                           reply_to  retweet_date  \
# 0        NaN                                                 []           NaN
# 1        NaN  [{'screen_name': 'GoingParabolic', 'name': 'Ja...           NaN
# 2        NaN  [{'screen_name': 'GoingParabolic', 'name': 'Ja...           NaN
# 3        NaN  [{'screen_name': 'GoingParabolic', 'name': 'Ja...           NaN
# 4        NaN  [{'screen_name': 'GoingParabolic', 'name': 'Ja...           NaN
#
#    translate trans_src trans_dest
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4        NaN       NaN        NaN
#
# [5 rows x 36 columns]

# %%
# Change index to date of the tweet
mcuban_btc.set_index('date', inplace = True)
mcuban_btc_tweets = mcuban_btc["tweet"]
mcuban_btc_tweets.head()
# Out:
# date
# 2021-09-17    Any one else notice how the BTC Maxis that scr...
# 2021-08-15    @GoingParabolic @DarinFeinstein @gladstein @Ch...
# 2021-08-15    @GoingParabolic @DarinFeinstein @gladstein @Ch...
# 2021-08-15    @GoingParabolic @DarinFeinstein @gladstein @Ch...
# 2021-08-15    @GoingParabolic @DarinFeinstein @gladstein @Ch...
# Name: tweet, dtype: object

# %%
# Turn list of tweets back into a dataframe
mcuban_btc_tweets_df = pd.DataFrame(mcuban_btc_tweets)   
mcuban_btc_tweets_df
# Out:
#                                                         tweet
# date
# 2021-09-17  Any one else notice how the BTC Maxis that scr...
# 2021-08-15  @GoingParabolic @DarinFeinstein @gladstein @Ch...
# 2021-08-15  @GoingParabolic @DarinFeinstein @gladstein @Ch...
# 2021-08-15  @GoingParabolic @DarinFeinstein @gladstein @Ch...
# 2021-08-15  @GoingParabolic @DarinFeinstein @gladstein @Ch...
# ...                                                       ...
# 2020-12-18  @jhamel It's actually late. More than 85pct of...
# 2020-12-18  @JackHar10524114 @MrHodl @AlanFreestone @glads...
# 2020-12-18  @_ConnerBrown_ Spoiler alert: btc is not suppo...
# 2020-12-18  @Alexwashere @gladstein And they all value tha...
# 2020-12-18  @BitcoinMacGyver @gladstein So the people who ...
#
# [183 rows x 1 columns]

# %%
# Import modules for sentiment analysis

import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Schmidt\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#Loop through the tweets using sentiment analysis and append to a list

#Set list and count variable
mcuban_btc_sentiment = []
count = 0

for tweet in mcuban_btc_tweets:
    try:
        date = mcuban_btc_tweets.index[count]
        sentiment = analyzer.polarity_scores(tweet)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        mcuban_btc_sentiment.append({
            "tweet": tweet,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu})
        count += 1
        
    except AttributeError:
        pass

#Turn the sentiment list into a date frame
mcuban_btc_sentiment = pd.DataFrame(mcuban_btc_sentiment)   
mcuban_btc_sentiment
# Out:
#                                                  tweet        date  compound  \
# 0    Any one else notice how the BTC Maxis that scr...  2021-09-17   -0.3400
# 1    @GoingParabolic @DarinFeinstein @gladstein @Ch...  2021-08-15    0.6478
# 2    @GoingParabolic @DarinFeinstein @gladstein @Ch...  2021-08-15    0.8440
# 3    @GoingParabolic @DarinFeinstein @gladstein @Ch...  2021-08-15   -0.5187
# 4    @GoingParabolic @DarinFeinstein @gladstein @Ch...  2021-08-15    0.2960
# ..                                                 ...         ...       ...
# 178  @jhamel It's actually late. More than 85pct of...  2020-12-18    0.2500
# 179  @JackHar10524114 @MrHodl @AlanFreestone @glads...  2020-12-18   -0.1531
# 180  @_ConnerBrown_ Spoiler alert: btc is not suppo...  2020-12-18    0.5719
# 181  @Alexwashere @gladstein And they all value tha...  2020-12-18    0.3400
# 182  @BitcoinMacGyver @gladstein So the people who ...  2020-12-18    0.9050
#
#      positive  negative  neutral
# 0       0.031     0.064    0.905
# 1       0.198     0.086    0.716
# 2       0.232     0.057    0.712
# 3       0.028     0.067    0.905
# 4       0.065     0.029    0.906
# ..        ...       ...      ...
# 178     0.087     0.000    0.913
# 179     0.095     0.136    0.769
# 180     0.320     0.000    0.680
# 181     0.118     0.000    0.882
# 182     0.227     0.000    0.773
#
# [183 rows x 6 columns]

# %%
# Load csv with all of Mark Cuban's eth tweets into a dataframe
mcuban_eth = pd.read_csv('mcuban_eth_tweets.csv')
mcuban_eth.head()
# Out:
#                     id      conversation_id  \
# 0  1426680961769562113  1426600841650319367
# 1  1413915899682332681  1413609800265515009
# 2  1396496065092734981  1396489151000817671
# 3  1393688018347823104  1393688018347823104
# 4  1392611938983632896  1392611938983632896
#
#                                   created_at        date      time  timezone  \
# 0  2021-08-14 18:03:42 Central Daylight Time  2021-08-14  18:03:42      -500
# 1  2021-07-10 12:39:54 Central Daylight Time  2021-07-10  12:39:54      -500
# 2  2021-05-23 10:59:42 Central Daylight Time  2021-05-23  10:59:42      -500
# 3  2021-05-15 17:01:31 Central Daylight Time  2021-05-15  17:01:31      -500
# 4  2021-05-12 17:45:34 Central Daylight Time  2021-05-12  17:45:34      -500
#
#     user_id username        name  place  ... geo source user_rt_id user_rt  \
# 0  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 1  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 2  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 3  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 4  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
#
#   retweet_id                                           reply_to  retweet_date  \
# 0        NaN  [{'screen_name': 'Atoms_to_Bits', 'name': 'Ada...           NaN
# 1        NaN  [{'screen_name': 'maqstik', 'name': 'Amrit Kum...           NaN
# 2        NaN  [{'screen_name': 'lawmaster', 'name': 'Larry C...           NaN
# 3        NaN                                                 []           NaN
# 4        NaN                                                 []           NaN
#
#    translate trans_src trans_dest
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4        NaN       NaN        NaN
#
# [5 rows x 36 columns]

# %%
# Change index to date of the tweet
mcuban_eth.set_index('date', inplace = True)
mcuban_eth_tweets = mcuban_eth["tweet"]
mcuban_eth_tweets.head()
# Out:
# date
# 2021-08-14    @Atoms_to_Bits @rothbardian88 @derekmross @Goi...
# 2021-07-10    @maqstik @Sr1ki @wholetthedasout But if you ge...
# 2021-05-23    @lawmaster I think this is the "Great Unwind"....
# 2021-05-15    That’s great !  I’m happy for your application...
# 2021-05-12    We at  https://t.co/VUydpLFzGh will continue t...
# Name: tweet, dtype: object

# %%
# Turn list of tweets back into a dataframe
mcuban_eth_tweets_df = pd.DataFrame(mcuban_eth_tweets)   
mcuban_eth_tweets_df
# Out:
#                                                         tweet
# date
# 2021-08-14  @Atoms_to_Bits @rothbardian88 @derekmross @Goi...
# 2021-07-10  @maqstik @Sr1ki @wholetthedasout But if you ge...
# 2021-05-23  @lawmaster I think this is the "Great Unwind"....
# 2021-05-15  That’s great !  I’m happy for your application...
# 2021-05-12  We at  https://t.co/VUydpLFzGh will continue t...
# 2021-05-08  @fintechfrank The reason eth has a chance to b...
# 2021-05-02  Eth Smart Contracts for De-Fi are better at en...
# 2021-05-02  Eth Smart Contracts are better, cheaper, faste...
# 2021-04-30  @spencernoon how much Eth is locked for stakin...
# 2021-04-29  Great. But you will put the $1m into a smart c...
# 2021-04-29  How about this. We set up a ln eth smart contr...
# 2021-04-29  @PeterMallouk Yup. All in on Netflix and Amazo...
# 2021-04-28  If you look at crypto assets whether eth, doge...
# 2021-04-28  @CoinDesk @TheEllenShow This is exactly why pe...
# 2021-04-24  @merket @jakeudell @chamath And my 2014 positi...
# 2021-04-17            @seanmc_eth @AlchemixFi always learning
# 2021-03-02  @CryptoHarper What i said a couple years ago w...
# 2021-03-02  Let me help Peter. Gold is hyped as much as Cr...
# 2021-02-18  @beingMicahWhite @eth_md @eulerbeats I didnt r...
# 2021-02-18  @beingMicahWhite @eth_md @eulerbeats which als...

# %%
#Loop through the tweets using sentiment analysis and append to a list

#Set list and count variable
mcuban_eth_sentiment = []
count = 0

for tweet in mcuban_eth_tweets:
    try:
        date = mcuban_eth_tweets.index[count]
        sentiment = analyzer.polarity_scores(tweet)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        mcuban_eth_sentiment.append({
            "tweet": tweet,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu})
        count += 1
        
    except AttributeError:
        pass

#Turn the sentiment list into a date frame
mcuban_eth_sentiment = pd.DataFrame(mcuban_eth_sentiment)   
mcuban_eth_sentiment
# Out:
#                                                 tweet        date  compound  \
# 0   @Atoms_to_Bits @rothbardian88 @derekmross @Goi...  2021-08-14    0.1779
# 1   @maqstik @Sr1ki @wholetthedasout But if you ge...  2021-07-10    0.0000
# 2   @lawmaster I think this is the "Great Unwind"....  2021-05-23    0.3400
# 3   That’s great !  I’m happy for your application...  2021-05-15    0.7609
# 4   We at  https://t.co/VUydpLFzGh will continue t...  2021-05-12    0.8658
# 5   @fintechfrank The reason eth has a chance to b...  2021-05-08    0.7684
# 6   Eth Smart Contracts for De-Fi are better at en...  2021-05-02    0.3182
# 7   Eth Smart Contracts are better, cheaper, faste...  2021-05-02    0.8126
# 8   @spencernoon how much Eth is locked for stakin...  2021-04-30    0.2640
# 9   Great. But you will put the $1m into a smart c...  2021-04-29    0.8294
# 10  How about this. We set up a ln eth smart contr...  2021-04-29    0.7096
# 11  @PeterMallouk Yup. All in on Netflix and Amazo...  2021-04-29    0.7717
# 12  If you look at crypto assets whether eth, doge...  2021-04-28    0.6597
# 13  @CoinDesk @TheEllenShow This is exactly why pe...  2021-04-28    0.8779
# 14  @merket @jakeudell @chamath And my 2014 positi...  2021-04-24    0.6428
# 15            @seanmc_eth @AlchemixFi always learning  2021-04-17    0.0000
# 16  @CryptoHarper What i said a couple years ago w...  2021-03-02    0.0000
# 17  Let me help Peter. Gold is hyped as much as Cr...  2021-03-02    0.8519
# 18  @beingMicahWhite @eth_md @eulerbeats I didnt r...  2021-02-18    0.5719
# 19  @beingMicahWhite @eth_md @eulerbeats which als...  2021-02-18    0.0000
#
#     positive  negative  neutral
# 0      0.036     0.000    0.964
# 1      0.000     0.000    1.000
# 2      0.097     0.054    0.848
# 3      0.205     0.072    0.723
# 4      0.245     0.000    0.755
# 5      0.150     0.000    0.850
# 6      0.119     0.070    0.810
# 7      0.208     0.000    0.792
# 8      0.108     0.000    0.892
# 9      0.175     0.055    0.770
# 10     0.120     0.023    0.857
# 11     0.152     0.036    0.812
# 12     0.132     0.000    0.868
# 13     0.195     0.024    0.781
# 14     0.119     0.000    0.881
# 15     0.000     0.000    1.000
# 16     0.000     0.000    1.000
# 17     0.190     0.000    0.810
# 18     0.079     0.000    0.921
# 19     0.000     0.000    1.000

# %%
# Load csv with all of Mark Cuban's doge tweets into a dataframe
mcuban_doge = pd.read_csv('mcuban_doge_tweets.csv')
mcuban_doge.head()
# Out:
#                     id      conversation_id  \
# 0  1427022703530237953  1427022076074856448
# 1  1427019271746605062  1426942035769102339
# 2  1427019085959811075  1426942035769102339
# 3  1426978389982949379  1426968262257094656
# 4  1426971530194468885  1426905539364200453
#
#                                   created_at        date      time  timezone  \
# 0  2021-08-15 16:41:39 Central Daylight Time  2021-08-15  16:41:39      -500
# 1  2021-08-15 16:28:01 Central Daylight Time  2021-08-15  16:28:01      -500
# 2  2021-08-15 16:27:17 Central Daylight Time  2021-08-15  16:27:17      -500
# 3  2021-08-15 13:45:34 Central Daylight Time  2021-08-15  13:45:34      -500
# 4  2021-08-15 13:18:19 Central Daylight Time  2021-08-15  13:18:19      -500
#
#     user_id username        name  place  ... geo source user_rt_id user_rt  \
# 0  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 1  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 2  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 3  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
# 4  16228398   mcuban  Mark Cuban    NaN  ... NaN    NaN        NaN     NaN
#
#   retweet_id                                           reply_to  retweet_date  \
# 0        NaN  [{'screen_name': 'Haymorrow', 'name': 'mo', 'i...           NaN
# 1        NaN  [{'screen_name': 'aravosis', 'name': 'John Ara...           NaN
# 2        NaN  [{'screen_name': 'aravosis', 'name': 'John Ara...           NaN
# 3        NaN                                                 []           NaN
# 4        NaN  [{'screen_name': 'CryptoPennyCO', 'name': 'Cry...           NaN
#
#    translate trans_src trans_dest
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2        NaN       NaN        NaN
# 3        NaN       NaN        NaN
# 4        NaN       NaN        NaN
#
# [5 rows x 36 columns]

# %%
# Change index to date of the tweet
mcuban_doge.set_index('date', inplace = True)
mcuban_doge_tweets = mcuban_doge["tweet"]
mcuban_doge_tweets.head()
# Out:
# date
# 2021-08-15    @Haymorrow @ProTheDoge I posted Mavs sales in ...
# 2021-08-15    @aravosis @rettlerb And between the Mavs and m...
# 2021-08-15    @aravosis @rettlerb The DOGE community was str...
# 2021-08-15    @Sacamonnai The Mavs have what we sold in merc...
# 2021-08-15    @CryptoPennyCO @ChainLinkGod I don’t prefer do...
# Name: tweet, dtype: object

# %%
# Turn list of tweets back into a dataframe
mcuban_doge_tweets_df = pd.DataFrame(mcuban_doge_tweets)   
mcuban_doge_tweets_df
# Out:
#                                                         tweet
# date
# 2021-08-15  @Haymorrow @ProTheDoge I posted Mavs sales in ...
# 2021-08-15  @aravosis @rettlerb And between the Mavs and m...
# 2021-08-15  @aravosis @rettlerb The DOGE community was str...
# 2021-08-15  @Sacamonnai The Mavs have what we sold in merc...
# 2021-08-15  @CryptoPennyCO @ChainLinkGod I don’t prefer do...
# 2021-08-15  Joel. that applies to everything.  Supply and ...
# 2021-08-15  @ChainLinkGod Difference is community. That is...
# 2021-08-15  @lartherab @ChadVE2 @gladstein @derekmross @Go...
# 2021-08-15  The point about DOGE that people miss is that ...
# 2021-08-15  @gladstein @derekmross @GoingParabolic The bes...
# 2021-08-14  I don't shill Doge. I shill the prods &amp; se...
# 2021-08-14  @justakidfromlbc @GoingParabolic I think the i...
# 2021-08-14  @Atoms_to_Bits @rothbardian88 @derekmross @Goi...
# 2021-08-14  @rothbardian88 @derekmross @GoingParabolic I'm...
# 2021-06-09  @boardroom @BobanMarjanovic @luka7doncic  http...
# 2021-05-15  @ANANDDB I never was anti crypto. Ive owned it...
# 2021-05-15  @CTHOMPS76132542 @IOHK_Charles I have said man...
# 2021-05-15  And for the record, the only DOGE I own is the...
# 2021-05-15  The reality is that even with crypto, SUPPLY A...
# 2021-05-15  Doge has "deterministic inflation" meaning the...
# 2021-05-12  We at  https://t.co/VUydpLFzGh will continue t...
# 2021-05-02  As long as more companies take doge for produc...
# 2021-05-02  Meme coins like Doge only work if they gain ut...
# 2021-04-30  @TradingPrice @george__mack i gave him 200 Dog...
# 2021-04-29  @PeterMallouk Actually It started with me sayi...
# 2021-04-28  If you look at crypto assets whether eth, doge...
# 2021-04-28  When was the last time you looked at your bank...
# 2021-04-28  @CoinDesk @TheEllenShow This is exactly why pe...
# 2021-04-26  Because Doge is the one coin that people actua...
# 2021-04-26  Just talked to my friends at @BitPay, they do ...
# 2021-04-16  To kinda quote a movie "Doge keeps going up, b...
# 2021-04-13  FYI, the Mavs sales in @dogecoin  have increas...
# 2021-04-02  Check out this #NFT for sale on Mintable! Pick...
# 2021-03-06  @Doge_Storm @dallasmavs I haven’t. I’m having ...
# 2021-03-05  To all you people getting all excitable about ...

# %%
#Loop through the tweets using sentiment analysis and append to a list

#Set list and count variable
mcuban_doge_sentiment = []
count = 0

for tweet in mcuban_doge_tweets:
    try:
        date = mcuban_doge_tweets.index[count]
        sentiment = analyzer.polarity_scores(tweet)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        mcuban_doge_sentiment.append({
            "tweet": tweet,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu})
        count += 1
        
    except AttributeError:
        pass

#Turn the sentiment list into a date frame
mcuban_doge_sentiment = pd.DataFrame(mcuban_doge_sentiment)   
mcuban_doge_sentiment
# Out:
#                                                 tweet        date  compound  \
# 0   @Haymorrow @ProTheDoge I posted Mavs sales in ...  2021-08-15    0.0000
# 1   @aravosis @rettlerb And between the Mavs and m...  2021-08-15    0.0000
# 2   @aravosis @rettlerb The DOGE community was str...  2021-08-15    0.8360
# 3   @Sacamonnai The Mavs have what we sold in merc...  2021-08-15    0.2263
# 4   @CryptoPennyCO @ChainLinkGod I don’t prefer do...  2021-08-15   -0.6310
# 5   Joel. that applies to everything.  Supply and ...  2021-08-15    0.9542
# 6   @ChainLinkGod Difference is community. That is...  2021-08-15    0.5719
# 7   @lartherab @ChadVE2 @gladstein @derekmross @Go...  2021-08-15    0.7579
# 8   The point about DOGE that people miss is that ...  2021-08-15    0.9274
# 9   @gladstein @derekmross @GoingParabolic The bes...  2021-08-15    0.3400
# 10  I don't shill Doge. I shill the prods &amp; se...  2021-08-14   -0.2617
# 11  @justakidfromlbc @GoingParabolic I think the i...  2021-08-14    0.3291
# 12  @Atoms_to_Bits @rothbardian88 @derekmross @Goi...  2021-08-14    0.1779
# 13  @rothbardian88 @derekmross @GoingParabolic I'm...  2021-08-14   -0.3291
# 14  @boardroom @BobanMarjanovic @luka7doncic  http...  2021-06-09    0.4574
# 15  @ANANDDB I never was anti crypto. Ive owned it...  2021-05-15    0.7401
# 16  @CTHOMPS76132542 @IOHK_Charles I have said man...  2021-05-15    0.5859
# 17  And for the record, the only DOGE I own is the...  2021-05-15    0.4588
# 18  The reality is that even with crypto, SUPPLY A...  2021-05-15    0.7509
# 19  Doge has "deterministic inflation" meaning the...  2021-05-15   -0.1779
# 20  We at  https://t.co/VUydpLFzGh will continue t...  2021-05-12    0.8658
# 21  As long as more companies take doge for produc...  2021-05-02    0.9093
# 22  Meme coins like Doge only work if they gain ut...  2021-05-02    0.9217
# 23  @TradingPrice @george__mack i gave him 200 Dog...  2021-04-30    0.4588
# 24  @PeterMallouk Actually It started with me sayi...  2021-04-29    0.0000
# 25  If you look at crypto assets whether eth, doge...  2021-04-28    0.6597
# 26  When was the last time you looked at your bank...  2021-04-28    0.5023
# 27  @CoinDesk @TheEllenShow This is exactly why pe...  2021-04-28    0.8779
# 28  Because Doge is the one coin that people actua...  2021-04-26    0.8674
# 29  Just talked to my friends at @BitPay, they do ...  2021-04-26    0.3274
# 30  To kinda quote a movie "Doge keeps going up, b...  2021-04-16    0.0000
# 31  FYI, the Mavs sales in @dogecoin  have increas...  2021-04-13    0.6027
# 32  Check out this #NFT for sale on Mintable! Pick...  2021-04-02    0.0000
# 33  @Doge_Storm @dallasmavs I haven’t. I’m having ...  2021-03-06    0.5562
# 34  To all you people getting all excitable about ...  2021-03-05    0.9595
#
#     positive  negative  neutral
# 0      0.000     0.000    1.000
# 1      0.000     0.000    1.000
# 2      0.235     0.000    0.765
# 3      0.119     0.000    0.881
# 4      0.000     0.179    0.821
# 5      0.260     0.020    0.720
# 6      0.110     0.000    0.890
# 7      0.333     0.000    0.667
# 8      0.254     0.027    0.719
# 9      0.051     0.024    0.925
# 10     0.027     0.085    0.888
# 11     0.055     0.000    0.945
# 12     0.036     0.000    0.964
# 13     0.058     0.082    0.860
# 14     0.200     0.000    0.800
# 15     0.136     0.000    0.864
# 16     0.107     0.000    0.893
# 17     0.065     0.000    0.935
# 18     0.165     0.030    0.805
# 19     0.077     0.091    0.832
# 20     0.245     0.000    0.755
# 21     0.247     0.000    0.753
# 22     0.236     0.000    0.764
# 23     0.188     0.000    0.812
# 24     0.000     0.000    1.000
# 25     0.132     0.000    0.868
# 26     0.108     0.000    0.892
# 27     0.195     0.024    0.781
# 28     0.162     0.026    0.812
# 29     0.061     0.000    0.939
# 30     0.000     0.000    1.000
# 31     0.130     0.000    0.870
# 32     0.000     0.000    1.000
# 33     0.418     0.000    0.582
# 34     0.341     0.000    0.659

# %%
# Load csv with all of Pan B's btc tweets into a dataframe
planb_btc = pd.read_csv('planb_btc_tweets.csv')
planb_btc.head()
# Out:
#                     id      conversation_id  \
# 0  1442780340276367362  1442772744450592771
# 1  1441343203475542028  1441335732895825924
# 2  1440963275664072704  1440806159955365895
# 3  1438411395893239808  1438153029052678159
# 4  1438161216128622594  1438153029052678159
#
#                                   created_at        date      time  timezone  \
# 0  2021-09-28 04:16:53 Central Daylight Time  2021-09-28  04:16:53      -500
# 1  2021-09-24 05:06:13 Central Daylight Time  2021-09-24  05:06:13      -500
# 2  2021-09-23 03:56:31 Central Daylight Time  2021-09-23  03:56:31      -500
# 3  2021-09-16 02:56:15 Central Daylight Time  2021-09-16  02:56:15      -500
# 4  2021-09-15 10:22:08 Central Daylight Time  2021-09-15  10:22:08      -500
#
#               user_id        username   name  place  ... geo source  \
# 0  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 1  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 2  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 3  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 4  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
#
#   user_rt_id user_rt retweet_id  \
# 0        NaN     NaN        NaN
# 1        NaN     NaN        NaN
# 2        NaN     NaN        NaN
# 3        NaN     NaN        NaN
# 4        NaN     NaN        NaN
#
#                                             reply_to  retweet_date  translate  \
# 0  [{'screen_name': 'CryptoExpoDan', 'name': 'Cry...           NaN        NaN
# 1  [{'screen_name': 'NoSleepTrader', 'name': 'Nos...           NaN        NaN
# 2  [{'screen_name': 'DatCryptoBoi', 'name': 'DatC...           NaN        NaN
# 3  [{'screen_name': 'CarlesMassa', 'name': 'Carlo...           NaN        NaN
# 4  [{'screen_name': 'BTC_Archive', 'name': 'Bitco...           NaN        NaN
#
#   trans_src trans_dest
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN
#
# [5 rows x 36 columns]

# %%
# Change index to date of the tweet
planb_btc.set_index('date', inplace = True)
planb_btc_tweets = planb_btc["tweet"]
planb_btc_tweets.head()
# Out:
# date
# 2021-09-28    @CryptoExpoDan S2F target of 100k is an averag...
# 2021-09-24    @NoSleepTrader Yeah bitcoin pumped too hard, I...
# 2021-09-23    @DatCryptoBoi @intocryptoverse Correct, but in...
# 2021-09-16                   @CarlesMassa @BTC_Archive Et voila
# 2021-09-15    @BTC_Archive Yes, and they closed the exits, t...
# Name: tweet, dtype: object

# %%
# Turn list of tweets back into a dataframe
planb_btc_tweets_df = pd.DataFrame(planb_btc_tweets)   
planb_btc_tweets_df
# Out:
#                                                         tweet
# date
# 2021-09-28  @CryptoExpoDan S2F target of 100k is an averag...
# 2021-09-24  @NoSleepTrader Yeah bitcoin pumped too hard, I...
# 2021-09-23  @DatCryptoBoi @intocryptoverse Correct, but in...
# 2021-09-16                 @CarlesMassa @BTC_Archive Et voila
# 2021-09-15  @BTC_Archive Yes, and they closed the exits, t...
# ...                                                       ...
# 2020-10-19  @antanst The cost (capex and opex) of 51% BTC ...
# 2020-10-19  @PeterAngel2019 BTC price is in its 3rd best m...
# 2020-10-17  @CarbonSteed thank you. it could also be stuff...
# 2020-10-16  ❓Why does #bitcoin price not go up with all th...
# 2020-10-15  Normal bitcoin transactions outbid the more fe...
#
# [383 rows x 1 columns]

# %%
#Loop through the tweets using sentiment analysis and append to a list

#Set list and count variable
planb_btc_sentiment = []
count = 0

for tweet in planb_btc_tweets:
    try:
        date = planb_btc_tweets.index[count]
        sentiment = analyzer.polarity_scores(tweet)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        planb_btc_sentiment.append({
            "tweet": tweet,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu})
        count += 1
        
    except AttributeError:
        pass

#Turn the sentiment list into a date frame
planb_btc_sentiment = pd.DataFrame(planb_btc_sentiment)   
planb_btc_sentiment
# Out:
#                                                  tweet        date  compound  \
# 0    @CryptoExpoDan S2F target of 100k is an averag...  2021-09-28   -0.3400
# 1    @NoSleepTrader Yeah bitcoin pumped too hard, I...  2021-09-24    0.5859
# 2    @DatCryptoBoi @intocryptoverse Correct, but in...  2021-09-23    0.4497
# 3                   @CarlesMassa @BTC_Archive Et voila  2021-09-16    0.0000
# 4    @BTC_Archive Yes, and they closed the exits, t...  2021-09-15    0.4019
# ..                                                 ...         ...       ...
# 378  @antanst The cost (capex and opex) of 51% BTC ...  2020-10-19   -0.6486
# 379  @PeterAngel2019 BTC price is in its 3rd best m...  2020-10-19    0.6696
# 380  @CarbonSteed thank you. it could also be stuff...  2020-10-17    0.6124
# 381  ❓Why does #bitcoin price not go up with all th...  2020-10-16    0.0000
# 382  Normal bitcoin transactions outbid the more fe...  2020-10-15    0.8360
#
#      positive  negative  neutral
# 0       0.059     0.116    0.825
# 1       0.230     0.062    0.708
# 2       0.059     0.000    0.941
# 3       0.000     0.000    1.000
# 4       0.109     0.000    0.891
# ..        ...       ...      ...
# 378     0.000     0.155    0.845
# 379     0.333     0.000    0.667
# 380     0.156     0.000    0.844
# 381     0.000     0.000    1.000
# 382     0.223     0.000    0.777
#
# [383 rows x 6 columns]

# %%
# Load csv with all of Pan B's eth tweets into a dataframe
planb_eth = pd.read_csv('planb_eth_tweets.csv')
planb_eth.head()
# Out:
#                     id      conversation_id  \
# 0  1421761930788749312  1421746201557405704
# 1  1392641441206312962  1392632189104185352
# 2  1392638519483539457  1392632189104185352
# 3  1392636271231737861  1392632189104185352
# 4  1392495498389557251  1392495498389557251
#
#                                   created_at        date      time  timezone  \
# 0  2021-08-01 04:17:14 Central Daylight Time  2021-08-01  04:17:14      -500
# 1  2021-05-12 19:42:48 Central Daylight Time  2021-05-12  19:42:48      -500
# 2  2021-05-12 19:31:11 Central Daylight Time  2021-05-12  19:31:11      -500
# 3  2021-05-12 19:22:15 Central Daylight Time  2021-05-12  19:22:15      -500
# 4  2021-05-12 10:02:52 Central Daylight Time  2021-05-12  10:02:52      -500
#
#               user_id        username   name  place  ... geo source  \
# 0  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 1  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 2  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 3  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 4  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
#
#   user_rt_id user_rt retweet_id  \
# 0        NaN     NaN        NaN
# 1        NaN     NaN        NaN
# 2        NaN     NaN        NaN
# 3        NaN     NaN        NaN
# 4        NaN     NaN        NaN
#
#                                             reply_to  retweet_date  translate  \
# 0  [{'screen_name': 'GregoryPeterJ', 'name': 'Pet...           NaN        NaN
# 1  [{'screen_name': 'sebirocs', 'name': 'Sebastia...           NaN        NaN
# 2  [{'screen_name': 'xrpmule', 'name': 'LEMONMULE...           NaN        NaN
# 3  [{'screen_name': 'xrpmule', 'name': 'LEMONMULE...           NaN        NaN
# 4                                                 []           NaN        NaN
#
#   trans_src trans_dest
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN
#
# [5 rows x 36 columns]

# %%
# Change index to date of the tweet
planb_eth.set_index('date', inplace = True)
planb_eth_tweets = planb_eth["tweet"]
planb_eth_tweets.head()
# Out:
# date
# 2021-08-01    @GregoryPeterJ @ETH_Ghost @G_CFP_MSc That is s...
# 2021-05-12    @sebirocs It is a marketing trick of Eth: PoS ...
# 2021-05-12    @xrpmule Xrp and Eth are dead as a decentraliz...
# 2021-05-12    @xrpmule Yes, without PoW bitcoin would be dea...
# 2021-05-12    ETH is now ~0.08 BTC and might even pump to 20...
# Name: tweet, dtype: object

# %%
# Turn list of tweets back into a dataframe
planb_eth_tweets_df = pd.DataFrame(planb_eth_tweets)   
planb_eth_tweets_df
# Out:
#                                                         tweet
# date
# 2021-08-01  @GregoryPeterJ @ETH_Ghost @G_CFP_MSc That is s...
# 2021-05-12  @sebirocs It is a marketing trick of Eth: PoS ...
# 2021-05-12  @xrpmule Xrp and Eth are dead as a decentraliz...
# 2021-05-12  @xrpmule Yes, without PoW bitcoin would be dea...
# 2021-05-12  ETH is now ~0.08 BTC and might even pump to 20...
# 2021-04-26  After this 2020 Vitalik tweet (BTC $9K) 2 thin...
# 2020-10-19  @antanst The cost (capex and opex) of 51% BTC ...

# %%
#Loop through the tweets using sentiment analysis and append to a list

#Set list and count variable
planb_eth_sentiment = []
count = 0

for tweet in planb_eth_tweets:
    try:
        date = planb_eth_tweets.index[count]
        sentiment = analyzer.polarity_scores(tweet)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        planb_eth_sentiment.append({
            "tweet": tweet,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu})
        count += 1
        
    except AttributeError:
        pass

#Turn the sentiment list into a date frame
planb_eth_sentiment = pd.DataFrame(planb_eth_sentiment)   
planb_eth_sentiment
# Out:
#                                                tweet        date  compound  \
# 0  @GregoryPeterJ @ETH_Ghost @G_CFP_MSc That is s...  2021-08-01   -0.5550
# 1  @sebirocs It is a marketing trick of Eth: PoS ...  2021-05-12   -0.7912
# 2  @xrpmule Xrp and Eth are dead as a decentraliz...  2021-05-12   -0.3612
# 3  @xrpmule Yes, without PoW bitcoin would be dea...  2021-05-12   -0.7925
# 4  ETH is now ~0.08 BTC and might even pump to 20...  2021-05-12    0.0000
# 5  After this 2020 Vitalik tweet (BTC $9K) 2 thin...  2021-04-26    0.7269
# 6  @antanst The cost (capex and opex) of 51% BTC ...  2020-10-19   -0.6486
#
#    positive  negative  neutral
# 0     0.000     0.104    0.896
# 1     0.062     0.268    0.670
# 2     0.030     0.070    0.899
# 3     0.121     0.208    0.671
# 4     0.000     0.000    1.000
# 5     0.136     0.000    0.864
# 6     0.000     0.155    0.845

# %%
# Load csv with all of Pan B's doge tweets into a dataframe
planb_doge = pd.read_csv('planb_doge_tweets.csv')
planb_doge.head()
# Out:
#                     id      conversation_id  \
# 0  1393318153418121226  1393318153418121226
# 1  1391071281282420738  1390974087762227201
# 2  1390980861101740038  1390974087762227201
# 3  1390980299421589505  1390974087762227201
# 4  1389706960883306512  1389703476935073793
#
#                                   created_at        date      time  timezone  \
# 0  2021-05-14 16:31:49 Central Daylight Time  2021-05-14  16:31:49      -500
# 1  2021-05-08 11:43:32 Central Daylight Time  2021-05-08  11:43:32      -500
# 2  2021-05-08 05:44:15 Central Daylight Time  2021-05-08  05:44:15      -500
# 3  2021-05-08 05:42:01 Central Daylight Time  2021-05-08  05:42:01      -500
# 4  2021-05-04 17:22:13 Central Daylight Time  2021-05-04  17:22:13      -500
#
#               user_id        username   name  place  ... geo source  \
# 0  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 1  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 2  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 3  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
# 4  918804624303382528  100trillionusd  PlanB    NaN  ... NaN    NaN
#
#   user_rt_id user_rt retweet_id  \
# 0        NaN     NaN        NaN
# 1        NaN     NaN        NaN
# 2        NaN     NaN        NaN
# 3        NaN     NaN        NaN
# 4        NaN     NaN        NaN
#
#                                             reply_to  retweet_date  translate  \
# 0                                                 []           NaN        NaN
# 1  [{'screen_name': 'roymaj', 'name': 'ROYMAJ', '...           NaN        NaN
# 2  [{'screen_name': 'naiiveclub', 'name': 'naiive...           NaN        NaN
# 3  [{'screen_name': 'unstoppablebtc', 'name': 'Un...           NaN        NaN
# 4  [{'screen_name': 'nakugo2d', 'name': 'dogukan'...           NaN        NaN
#
#   trans_src trans_dest
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN
#
# [5 rows x 36 columns]

# %%
# Change index to date of the tweet
planb_doge.set_index('date', inplace = True)
planb_doge_tweets = planb_doge["tweet"]
planb_doge_tweets.head()
# Out:
# date
# 2021-05-14    Roger Ver -&gt; BCH Mark Zuckerberg -&gt; Libr...
# 2021-05-08            @roymaj 1 $Doge now buys you 1150 Sats !!
# 2021-05-08                    @naiiveclub Sats is the next Doge
# 2021-05-08                       @unstoppablebtc Sats &gt; Doge
# 2021-05-04    @nakugo2d buy doge if you must .. and give us ...
# Name: tweet, dtype: object

# %%
# Turn list of tweets back into a dataframe
planb_doge_tweets_df = pd.DataFrame(planb_doge_tweets)   
planb_doge_tweets_df
# Out:
#                                                         tweet
# date
# 2021-05-14  Roger Ver -&gt; BCH Mark Zuckerberg -&gt; Libr...
# 2021-05-08          @roymaj 1 $Doge now buys you 1150 Sats !!
# 2021-05-08                  @naiiveclub Sats is the next Doge
# 2021-05-08                     @unstoppablebtc Sats &gt; Doge
# 2021-05-04  @nakugo2d buy doge if you must .. and give us ...

# %%
#Loop through the tweets using sentiment analysis and append to a list

#Set list and count variable
planb_doge_sentiment = []
count = 0

for tweet in planb_doge_tweets:
    try:
        date = planb_doge_tweets.index[count]
        sentiment = analyzer.polarity_scores(tweet)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        planb_doge_sentiment.append({
            "tweet": tweet,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu})
        count += 1
        
    except AttributeError:
        pass

#Turn the sentiment list into a date frame
planb_doge_sentiment = pd.DataFrame(planb_doge_sentiment)   
planb_doge_sentiment
# Out:
#                                                tweet        date  compound  \
# 0  Roger Ver -&gt; BCH Mark Zuckerberg -&gt; Libr...  2021-05-14    0.7941
# 1          @roymaj 1 $Doge now buys you 1150 Sats !!  2021-05-08    0.0000
# 2                  @naiiveclub Sats is the next Doge  2021-05-08    0.0000
# 3                     @unstoppablebtc Sats &gt; Doge  2021-05-08    0.0000
# 4  @nakugo2d buy doge if you must .. and give us ...  2021-05-04    0.0000
#
#    positive  negative  neutral
# 0     0.152       0.0    0.848
# 1     0.000       0.0    1.000
# 2     0.000       0.0    1.000
# 3     0.000       0.0    1.000
# 4     0.000       0.0    1.000
